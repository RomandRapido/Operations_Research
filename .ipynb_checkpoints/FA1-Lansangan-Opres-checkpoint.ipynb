# %% [markdown]
# <div style="text-align: center;"> <h3>Operations Research</h3>
# <h5>Formative Assessment 1 (Part 1)</h5>
# <h5><u>By Romand Lansangan</u></h5>
#     </div>
#
# ---

# %% [markdown]
# ## Item 1
# 1. The Primo Insurance Company is introducing two new product lines: special risk insurance and mortgages. The expected profit is 5 dollar per unit on special risk insurance and 2 dollar per unit on mortgages. Management wishes to establish sales quotas for the new product lines to maximize total expected profit. The work requirements are as follows:
#
# ![image.png](attachment:251d5df8-d705-457a-b8fe-7840577b61b9.png)
#
# ### Linear Model
# #### Decision Variables
# $x$ number of work-hours for special risk
#
# $y$ number of work-hours for mortgage.
#
# #### Objective Function
# Maximize $P=2x+2y$
#
# #### Constraints
# $x,y \geq 0$
#
# $3x + 2y \leq 2400$
#
# $y \leq 800$
#
# $2x \leq 1200$
#
# ### Solution via Graphical Method
# <table>
#   <tr>
#     <td> <img src="attachment:2d6351f4-1a8f-4e05-badd-aed8c59b401b.png"  alt="1" width = 360px height = 640px ></td>
#     <td><img src="attachment:6b31b1eb-3987-482b-84b9-20824e31113f.png" alt="2" width = 360px height = 640px></td>
#    </tr>
# </table>
# The shade region is the feasible region.
#
# To input the objective function $P=2x+2y$
# <img src="attachment:c5237ea9-fdd5-4329-a6b8-f3f2af82aa6d.png" alt="1" width="360" height="640" style="display: block; margin-left: auto; margin-right: auto;">
#
# #### Solution:
# $(x,y) = (600,300)$
#
# ### Final P
# $P = 2x+3y = 2(600) + 3(300) = \$2100 $

# %% [markdown]
# ## Item 2
# #### Model
# Minimize $Z=40x_1 + 50x_2$
#
# #### Constraints
# $2x_1 + 3x_2 \geq 30$
#
# $x_1 + x_2 \geq 12$
#
# $2x_1 + x_2 \geq 20$
#
# #### Solution view Graphical Method
# <table>
#   <tr>
#     <td> <img src="attachment:b3c18240-d98d-4134-bc80-4f21e441d7f5.png"  alt="1" width = 360px height = 640px ></td>
#     <td><img src="attachment:b673b27e-1d46-4dd7-8c0e-8e763f4f4590.png" alt="2" width = 360px height = 640px></td>
#    </tr>
# </table>
#
# The shaded region is the feasible region.
#
# To input the objective function $Z=40x_1 + 50x_2$
# <img src="attachment:99e33738-d0b3-4134-8c96-74da2793d72a.png" alt="1" width="360" height="640" style="display: block; margin-left: auto; margin-right: auto;">
#
# #### Solution:
# $(x_1, x_2)=(7.5,5)$
#
# $Z=40x_1 + 50x_2 = 40(7.5)+50(5)=550$
#
# #### If objective function is $Z=40x_1 + 70x_2$
# <img src="attachment:0061eadb-fd7b-463b-98c5-6871a5950e2d.png" alt="1" width="360" height="640" style="display: block; margin-left: auto; margin-right: auto;">
#
# $(x_1, x_2)=(15,0)$
#
# $Z=40x_1 + 70x_2 = 40(15)+50(0)=600$
#
# Both the solution and the value of Z will change. The Z increases so this isn't ideal considering we are trying to minimize the Z.
#
# #### If third constraint is $2x_1 + x_2 \geq 15$
# <img src="attachment:c2a240cf-9c8a-4872-a8c3-6864303e6e5b.png" alt="1" width="360" height="640" style="display: block; margin-left: auto; margin-right: auto;">
#
# $(x_1, x_2)=(3,9)$
#
# $Z=40x_1 + 50x_2 = 40(3)+50(9)=570$
#
# So the Z will increase compared to the original constraints, which isn't ideal considering we are trying to minimize here.
